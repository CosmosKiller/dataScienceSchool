# %%
import pandas as pd
import numpy as np

# %%
books_df = pd.read_csv('bestsellers-with-categories.csv', sep=',', header=0, names=['Nombre', 'Autor', 'Calificación', 'Reviews', 'Precio', 'Año', 'Género'])
books_df.head(2)
# Out:
#                           Nombre         Autor  Calificación  Reviews  Precio  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith           4.7    17350       8
# 1              11/22/63: A Novel  Stephen King           4.6     2052      22
#
#     Año       Género
# 0  2016  Non Fiction
# 1  2011      Fiction

# %%
books_copy = books_df.copy()

# %% [markdown]
# ## **Drop columns**

# %%
books_copy.drop('Género', axis=1, inplace=True)
books_copy.head(2)
# Out:
#                           Nombre         Autor  Calificación  Reviews  Precio  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith           4.7    17350       8
# 1              11/22/63: A Novel  Stephen King           4.6     2052      22
#
#     Año
# 0  2016
# 1  2011

# %%
books_df.head(2)
# Out:
#                           Nombre         Autor  Calificación  Reviews  Precio  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith           4.7    17350       8
# 1              11/22/63: A Novel  Stephen King           4.6     2052      22
#
#     Año       Género
# 0  2016  Non Fiction
# 1  2011      Fiction

# %%
books_copy = books_copy.drop('Año', axis=1)

# %%
books_copy.head(2)
# Out:
#                           Nombre         Autor  Calificación  Reviews  Precio
# 0  10-Day Green Smoothie Cleanse      JJ Smith           4.7    17350       8
# 1              11/22/63: A Novel  Stephen King           4.6     2052      22

# %%
del books_copy['Precio']

# %%
books_copy.head(2)
# Out:
#                           Nombre         Autor  Calificación  Reviews
# 0  10-Day Green Smoothie Cleanse      JJ Smith           4.7    17350
# 1              11/22/63: A Novel  Stephen King           4.6     2052

# %% [markdown]
# ##  **Drop rows**

# %%
books_copy2 = books_df.copy()

# %%
books_df.head(2)
# Out:
#                           Nombre         Autor  Calificación  Reviews  Precio  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith           4.7    17350       8
# 1              11/22/63: A Novel  Stephen King           4.6     2052      22
#
#     Año       Género
# 0  2016  Non Fiction
# 1  2011      Fiction

# %%
books_copy2.drop(range(0,10), axis=0).head(2)
# Out:
#                                                Nombre             Autor  \
# 10                          A Man Called Ove: A Novel   Fredrik Backman
# 11  A Patriot's History of the United States: From...  Larry Schweikart
#
#     Calificación  Reviews  Precio   Año       Género
# 10           4.6    23848       8  2017      Fiction
# 11           4.6      460       2  2010  Non Fiction

# %% [markdown]
# ## **Add columns**

# %%
books_df.head(2)
# Out:
#                           Nombre         Autor  Calificación  Reviews  Precio  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith           4.7    17350       8
# 1              11/22/63: A Novel  Stephen King           4.6     2052      22
#
#     Año       Género
# 0  2016  Non Fiction
# 1  2011      Fiction

# %%
books_df['Nueva _Columna'] = np.nan
books_df.head(2)
# Out:
#                           Nombre         Autor  Calificación  Reviews  Precio  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith           4.7    17350       8
# 1              11/22/63: A Novel  Stephen King           4.6     2052      22
#
#     Año       Género  Nueva _Columna
# 0  2016  Non Fiction             NaN
# 1  2011      Fiction             NaN

# %%
books_df.shape[0]
# Out:
# 550

# %%
data = np.arange(0, books_df.shape[0])

# %%
books_df['Rango'] = data
books_df
# Out:
#                                                 Nombre  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                         Autor  Calificación  Reviews  Precio   Año  \
# 0                    JJ Smith           4.7    17350       8  2016
# 1                Stephen King           4.6     2052      22  2011
# 2          Jordan B. Peterson           4.7    18979      15  2018
# ...

# %% [markdown]
# ## **Add rows**

# %%
books_df.append(books_df)
# Out:
# /tmp/ipykernel_8523/539968215.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   books_df.append(books_df)
#                                                 Nombre  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                         Autor  Calificación  Reviews  Precio   Año  \
# ...

# %% [markdown]
# ## **Another way to filter**

# %% [markdown]
# Si quieren borrar un elemento en especifico por ejemplo un autor
#
# Obtenemos los indices donde se encuentra el autor que queremos borrar

# %%
books_df.head(11)
# Out:
#                                                Nombre  \
# 0                       10-Day Green Smoothie Cleanse
# 1                                   11/22/63: A Novel
# 2             12 Rules for Life: An Antidote to Chaos
# 3                              1984 (Signet Classics)
# 4   5,000 Awesome Facts (About Everything!) (Natio...
# 5       A Dance with Dragons (A Song of Ice and Fire)
# 6   A Game of Thrones / A Clash of Kings / A Storm...
# 7                      A Gentleman in Moscow: A Novel
# 8       A Higher Loyalty: Truth, Lies, and Leadership
# 9                           A Man Called Ove: A Novel
# 10                          A Man Called Ove: A Novel
#
#                        Autor  Calificación  Reviews  Precio   Año  \
# 0                   JJ Smith           4.7    17350       8  2016
# 1               Stephen King           4.6     2052      22  2011
# 2         Jordan B. Peterson           4.7    18979      15  2018
# ...

# %%
index_author=books_df[books_df['Autor']=="Fredrik Backman"].index
index_author
# Out:
# Int64Index([9, 10], dtype='int64')

# %% [markdown]
# Le pasamos ese indice a drop para borrarlo

# %%
books_df.drop(index_author,inplace=True)
books_df.head(11)
# Out:
#                                                Nombre  \
# 0                       10-Day Green Smoothie Cleanse
# 1                                   11/22/63: A Novel
# 2             12 Rules for Life: An Antidote to Chaos
# 3                              1984 (Signet Classics)
# 4   5,000 Awesome Facts (About Everything!) (Natio...
# 5       A Dance with Dragons (A Song of Ice and Fire)
# 6   A Game of Thrones / A Clash of Kings / A Storm...
# 7                      A Gentleman in Moscow: A Novel
# 8       A Higher Loyalty: Truth, Lies, and Leadership
# 11  A Patriot's History of the United States: From...
# 12                            A Stolen Life: A Memoir
#
#                        Autor  Calificación  Reviews  Precio   Año  \
# 0                   JJ Smith           4.7    17350       8  2016
# 1               Stephen King           4.6     2052      22  2011
# 2         Jordan B. Peterson           4.7    18979      15  2018
# ...
