# %%
import pandas as pd

# %%
books_df = pd.read_csv('bestsellers-with-categories.csv', sep=',', header=0, names=['Nombre', 'Autor', 'Calificación', 'Reviews', 'Precio', 'Año', 'Género'])
books_df
# Out:
#                                                 Nombre  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                         Autor  Calificación  Reviews  Precio   Año  \
# 0                    JJ Smith           4.7    17350       8  2016
# 1                Stephen King           4.6     2052      22  2011
# 2          Jordan B. Peterson           4.7    18979      15  2018
# ...

# %%
books_df[0:4]
# Out:
#                                     Nombre               Autor  Calificación  \
# 0            10-Day Green Smoothie Cleanse            JJ Smith           4.7
# 1                        11/22/63: A Novel        Stephen King           4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson           4.7
# 3                   1984 (Signet Classics)       George Orwell           4.7
#
#    Reviews  Precio   Año       Género
# 0    17350       8  2016  Non Fiction
# 1     2052      22  2011      Fiction
# 2    18979      15  2018  Non Fiction
# 3    21424       6  2017      Fiction

# %%
books_df[['Nombre', 'Autor', 'Año']]
# Out:
#                                                 Nombre  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                         Autor   Año
# 0                    JJ Smith  2016
# 1                Stephen King  2011
# 2          Jordan B. Peterson  2018
# 3               George Orwell  2017
# 4    National Geographic Kids  2019
# ..                        ...   ...
# 545               Jeff Kinney  2019
# ...

# %% [markdown]
# ## **Loc**

# %%
books_df.loc[0:4, ['Nombre', 'Autor']]
# Out:
#                                               Nombre                     Autor
# 0                      10-Day Green Smoothie Cleanse                  JJ Smith
# 1                                  11/22/63: A Novel              Stephen King
# 2            12 Rules for Life: An Antidote to Chaos        Jordan B. Peterson
# 3                             1984 (Signet Classics)             George Orwell
# 4  5,000 Awesome Facts (About Everything!) (Natio...  National Geographic Kids

# %%
books_df.loc[:, ['Reviews']] * - 1
# Out:
#      Reviews
# 0     -17350
# 1      -2052
# 2     -18979
# 3     -21424
# 4      -7665
# ..       ...
# 545    -9413
# 546   -14331
# 547   -14331
# 548   -14331
# 549   -14331
#
# [550 rows x 1 columns]

# %%
psg_new_dict = {
   'Jugador': ['Navas','Mbappe','Neymar','Messi'],
   'Altura': [183.0, 170.0, 170.0, 165.0],
   'Goles': [2, 200, 200, 200]
}
psg_df = pd.DataFrame(psg_new_dict, index=['Juan', 'Quilina', 'Juan', 'Lionel']) #Index are now names
psg_df
# Out:
#         Jugador  Altura  Goles
# Juan      Navas   183.0      2
# Quilina  Mbappe   170.0    200
# Juan     Neymar   170.0    200
# Lionel    Messi   165.0    200

# %%
psg_df.loc[['Juan', 'Lionel'], 'Goles'] #Now we can filter values using player names
# Out:
# Juan        2
# Juan      200
# Lionel    200
# Name: Goles, dtype: int64

# %% [markdown]
# ## **Iloc**

# %%
books_df.iloc[:]
# Out:
#                                                 Nombre  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                         Autor  Calificación  Reviews  Precio   Año  \
# 0                    JJ Smith           4.7    17350       8  2016
# 1                Stephen King           4.6     2052      22  2011
# 2          Jordan B. Peterson           4.7    18979      15  2018
# ...

# %%
books_df.iloc[:, 0:3]
# Out:
#                                                 Nombre  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                         Autor  Calificación
# 0                    JJ Smith           4.7
# 1                Stephen King           4.6
# 2          Jordan B. Peterson           4.7
# 3               George Orwell           4.7
# 4    National Geographic Kids           4.8
# ...

# %%
books_df.iloc[1,3] * -1
# Out:
# -2052

# %%
books_df.iloc[:2, 2:]
# Out:
#    Calificación  Reviews  Precio   Año       Género
# 0           4.7    17350       8  2016  Non Fiction
# 1           4.6     2052      22  2011      Fiction

# %%
psg_df.iloc[0:2, :]
# Out:
#         Jugador  Altura  Goles
# Juan      Navas   183.0      2
# Quilina  Mbappe   170.0    200
